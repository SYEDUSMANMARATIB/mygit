# %% [markdown]
# # Name:
# # Roll No.:
# # Assignment 6

# %% [markdown]
# # Instruction

# %% [markdown]
# 1. Don’t plagiarize, Plagiarism would lead to straight zero
# 2. Clearly mention your NAME and ROLL NO#.
# 3. Late submissions are not allowed. Start Early.

# %%
#import libraries
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
#from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup as soup
from bs4 import BeautifulSoup

# %% [markdown]
# # Question 1

# %% [markdown]
# Scrape 2 pages of the reviews for a single product listing using product URL.<br /> Note: Product must have more than 1 review page. The code must be generic and should work for every product listing URL, with proper checks in place.

# %%
url = 'input url here'

# %%
#Output
df
# Out:
#            Name                                        Review text
# 0     Nabeel B.  Cellphone is great, was delivered on said time...
# 1     Salman R.  Great response excellent delivery time and pro...
# 2   Mohammad H.  One of the best in it's category. highly recom...
# 3         M***.        Very good product daraz good service thankx
# 4      hamxa M.                  Original product and good packing
# 5    Saqlain A.  Sir warranty card pr koi date ya sign nai to b...
# 6          M D.  Mobile is original but seller is too lazy in t...
# 7         N***.      Phone is perfect but now prices are increased
# 8      umair K.                   best phone in this price range.
# 9      Imran K.                                 original product 👍

# %% [markdown]
# # Question 2

# %% [markdown]
# Scrape 80 items for a keyword search e.g., 'mobile covers'<br/>Note: Must use "click()" function of webElement, URL changing for pages is not allowed. The code must be generic and should work for every keyword, with proper checks in place. Bonus for also scraping country and Daraz Mall availability.

# %%
n=input("Enter search words: ")

n=n.replace(' ','+')
n="mobile+covers"
link1="https://www.daraz.pk/catalog/?q="
link2="&_keyori=ss&from=input&spm=a2a0e.home.search.go.6a274937IJxjwH"
link=link1+n+link2
print(link)
driver = webdriver.Chrome()
driver.get(link)
#code = requests.get(final_link)
page = soup(driver.page_source, 'html.parser')
# products = page.find('div', {'class': 'c1_t2i'})


Name=[]
Daraz_Mall=[]
Original_Price =[]
Discounted_Price =[]
Rating =[]
Reviews =[]
Seller_Country=[]
Total_Sellers=0
Average_Price=0
Average_Ratings=0
Average_Reviews=0

source = driver.page_source
soup = BeautifulSoup(source)
m=0
for a in soup.findAll(attrs={'class':'c16H9d'}):
    m=m+1


# # Name

# In[158]:


for i in range(1,m+1):
    
    if i==1:
        
        try:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')
            
        except:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')  
            
    else:
        
        try:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')
            
        except:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')          
            
    Name.append(target_name.text)


# # Daraz Mall

# In[159]:


d=soup.find_all('div', class_='c3vCyH')
k="""<div class="c3vCyH"><i class="ic-dynamic-badge ic-dynamic-badge-lazMall ic-dynamic-group-1" style='background-image: url("//laz-img-cdn.alicdn.com/tfs/TB1rYuurhTpK1RjSZFMXXbG_VXa-205-48.png"); width: 68.3333px; height: 16px;'></i></div>"""

for i in d:
    if(str(i) == k):
            Daraz_Mall.append("Yes")
    else:
        Daraz_Mall.append("No") 


# # Original Price And Discounted Price

# In[160]:


for i in range(1,m+1):
    try:
        target_dprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[4]/span[1]/del')
    except:
        target_dprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[3]/span')
    
#     target_dprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[3]/span')
    
#     Original_Price.append(target_oprice.text)
    Discounted_Price.append(target_dprice.text)


# # Average Price

# In[161]:


sum=0
a=0
for i in Original_Price:
    x = i.replace("Rs.", "")
    x = x.replace(",", "")
    x = x.replace(" ", "")
    sum=sum+int(x)
    a=a+1
if a > 0:
    Average_Price=sum/a
else:
    Average_Price=0


# # Reviews

# In[162]:


for i in range(1,m+1):
    try:
        target_reviews=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[5]/div/span')
        Reviews.append(target_reviews.text)
    except:
        target_reviews="0"
        Reviews.append(target_reviews)


# # Average Reviews

# In[163]:


sum=0
a=0
for i in Reviews:
    x = i.replace("(", "")
    x = x.replace(")", "")
    x = x.replace(" ", "")
    x = x.replace("NILL", "0")
    sum=sum+int(x)
    a=a+1
if a > 0:
    Average_Reviews=sum/a
else:
    Average_Reviews=0


# # Location

# In[164]:


for i in range(1,m+1):
    target_loc=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[5]/span')
    Seller_Country.append(target_loc.text)


# # Rating

# In[165]:


a=0
sum=0
target_rating = soup.find_all("div", {"class" : "c2prKC"})
for i in range(0,(len(target_rating))):
    value = target_rating[i]
    rating = value.find('div', class_ = 'c15YQ9')
    strng =str(rating)
    two =strng.count("c3dn4k cbDGcO")
    three =strng.count("c3dn4k c3fsPU")
    four = strng.count("c3dn4k c1e2gb")
    five =strng.count("c3dn4k c3An30")
    six = strng.count("c3dn4k c3DcGB")
    seven =strng.count("c3dn4k c1wCjy")
    eight =strng.count("c3dn4k c17YMy")
    nine =strng.count("c3dn4k cF1vkb")
    full=strng.count("c3dn4k c3EEAg")
    two*=0.2
    three*=0.3
    four*=0.4
    five*=0.5
    six*=0.6
    seven*=0.7
    eight*=0.8
    nine*=0.9
    ratings=two+three+four+five+six+seven+eight+nine+full
    sum=ratings+sum
    a=a+1
    Rating.append(ratings)
Average_Rating=sum/a

df = pd.DataFrame(Name,columns=[' Name']) 
df['Price'] = Discounted_Price
df[' Rating'] = Rating
df[' Reviews'] = Reviews
print(df)
driver.quit()
# Out:
# Enter search words: dfg
# https://www.daraz.pk/catalog/?q=mobile+covers&_keyori=ss&from=input&spm=a2a0e.home.search.go.6a274937IJxjwH
# <ipython-input-16-94e9bb9b11ba>:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')
# <ipython-input-16-94e9bb9b11ba>:53: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')
# <ipython-input-16-94e9bb9b11ba>:83: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_dprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[4]/span[1]/del')
# ...

# %%
query = 'mobile covers'
url = 'form complete url from query given above by appending to actual url'

# %%
#Output
df
# Out:
#                                                  Name  Price  Stars  Reviews
# 0   Lenuo Luxury 6D Plating Soft Casing Silicone S...    837    4.6       14
# 1   Lenuo Luxury 6D Plating Soft Casing Silicone S...    837    4.7       23
# 2   Xiaomi Redmi Note 4 Case , Smoky Matte Shock P...    249    4.9       33
# 3   Huawei Nova Plus MATTE BLACK FLEXIBLE TPU CASE...    149    5.0        5
# 4   For Sony Xperia XZ3 Heavy Duty Armor Tough Hyb...    649    5.0       25
# ..                                                ...    ...    ...      ...
# 75  Xiaomi Redmi Note 7 / Note 7Pro Case , Smoky M...    249    4.7       46
# 76  Xiaomi Poco F3 Case , Soft TPU Camera Protecti...    185    4.9       35
# 77  Infinix Note 10 Pro , Full Protection Vinyl Sk...     99    4.6      112
# 78  Huawei Nova 3i Antishock Drop Resistance Armor...    449    5.0       58
# 79  Handfree Cover Charger Hard Case eva Coin Carr...    127    4.7       75
#
# [80 rows x 4 columns]

# %% [markdown]
# # Question 3

# %% [markdown]
# Which Products are on Flash sale? Display Product name, Actual Price, Discounted Price, Discount Percentage, Rating, No. of Reviews, Top 3 reviews displayed.
#
# Display output must be like this. Products may vary.

# %%
# n=input("Enter search words: ")

n=n.replace(' ','+')
link1="https://www.daraz.pk/catalog/?q="
link2="&_keyori=ss&from=input&spm=a2a0e.home.search.go.6a274937IJxjwH"
link="https://www.daraz.pk/catalog/?q=flash+sale&_keyori=ss&from=input&spm=a2a0e.home.search.go.6a274937IJxjwH"
print(link)
driver = webdriver.Chrome()
driver.get(link)
#code = requests.get(final_link)
page = soup(driver.page_source, 'html.parser')
# products = page.find('div', {'class': 'c1_t2i'})


Name=[]
Daraz_Mall=[]
Original_Price =[]
Discounted_Price =[]
Rating =[]
Reviews =[]
Seller_Country=[]
Total_Sellers=0
Average_Price=0
Average_Ratings=0
Average_Reviews=0

source = driver.page_source
soup = BeautifulSoup(source)
m=0
for a in soup.findAll(attrs={'class':'c16H9d'}):
    m=m+1


# # Name

# In[158]:


for i in range(1,m+1):
    
    if i==1:
        
        try:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')
            
        except:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')  
            
    else:
        
        try:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')
            
        except:
            target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')          
            
    Name.append(target_name.text)


# # Daraz Mall

# In[159]:


d=soup.find_all('div', class_='c3vCyH')
k="""<div class="c3vCyH"><i class="ic-dynamic-badge ic-dynamic-badge-lazMall ic-dynamic-group-1" style='background-image: url("//laz-img-cdn.alicdn.com/tfs/TB1rYuurhTpK1RjSZFMXXbG_VXa-205-48.png"); width: 68.3333px; height: 16px;'></i></div>"""

for i in d:
    if(str(i) == k):
            Daraz_Mall.append("Yes")
    else:
        Daraz_Mall.append("No") 


# # Original Price And Discounted Price

# In[160]:


for i in range(1,m+1):
    try:
        target_oprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[4]/span[1]/del')
    except:
        target_oprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[3]/span')
    
    target_dprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[3]/span')
    
    Original_Price.append(target_oprice.text)
    Discounted_Price.append(target_dprice.text)


# # Average Price

# In[161]:


sum=0
a=0
for i in Original_Price:
    x = i.replace("Rs.", "")
    x = x.replace(",", "")
    x = x.replace(" ", "")
    sum=sum+int(x)
    a=a+1
if a > 0:
    Average_Price=sum/a
else:
    Average_Price=0


# # Reviews

# In[162]:


for i in range(1,m+1):
    try:
        target_reviews=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[5]/div/span')
        Reviews.append(target_reviews.text)
    except:
        target_reviews="0"
        Reviews.append(target_reviews)


# # Average Reviews

# In[163]:


sum=0
a=0
for i in Reviews:
    x = i.replace("(", "")
    x = x.replace(")", "")
    x = x.replace(" ", "")
    x = x.replace("NILL", "0")
    sum=sum+int(x)
    a=a+1
if a > 0:
    Average_Reviews=sum/a
else:
    Average_Reviews=0


# # Location

# In[164]:


for i in range(1,m+1):
    target_loc=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[5]/span')
    Seller_Country.append(target_loc.text)


# # Rating

# In[165]:


a=0
sum=0
target_rating = soup.find_all("div", {"class" : "c2prKC"})
for i in range(0,(len(target_rating))):
    value = target_rating[i]
    rating = value.find('div', class_ = 'c15YQ9')
    strng =str(rating)
    two =strng.count("c3dn4k cbDGcO")
    three =strng.count("c3dn4k c3fsPU")
    four = strng.count("c3dn4k c1e2gb")
    five =strng.count("c3dn4k c3An30")
    six = strng.count("c3dn4k c3DcGB")
    seven =strng.count("c3dn4k c1wCjy")
    eight =strng.count("c3dn4k c17YMy")
    nine =strng.count("c3dn4k cF1vkb")
    full=strng.count("c3dn4k c3EEAg")
    two*=0.2
    three*=0.3
    four*=0.4
    five*=0.5
    six*=0.6
    seven*=0.7
    eight*=0.8
    nine*=0.9
    ratings=two+three+four+five+six+seven+eight+nine+full
    sum=ratings+sum
    a=a+1
    Rating.append(ratings)
Average_Rating=sum/a


# # Making A DataFrame

# In[166]:


df = pd.DataFrame(Name,columns=[' Name']) 
df[' Daraz Mall?'] = Daraz_Mall
df[' Original Price'] = Original_Price
# df[' Discounted Price'] = Discounted_Price
df[' Rating'] = Rating
df[' Reviews'] = Reviews
df[' Seller Country'] = Seller_Country
df.to_csv('sample.csv')
driver.quit()
# Out:
# https://www.daraz.pk/catalog/?q=flash+sale&_keyori=ss&from=input&spm=a2a0e.home.search.go.6a274937IJxjwH
# <ipython-input-3-26928af10030>:44: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]/div/div/div[2]/div[2]/a')
# <ipython-input-3-26928af10030>:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_name=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[2]/a')
# <ipython-input-3-26928af10030>:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   target_oprice=driver.find_element_by_xpath('//*[@id="root"]/div/div[2]/div[1]/div/div[1]/div[2]/div['+str(i)+']/div/div/div[2]/div[4]/span[1]/del')
# ...

# %%
#Run this cell to see output
pd.read_csv('sample.csv')
# Out:
#     Unnamed: 0                                               Name  \
# 0            0  FLASH SALE Egg Beater Machine Electric 7 Speed...
# 1            1  [FLASH SALE] 7 Speed Electric Hand Mixer Egg B...
# 2            2  Gionee Wired Earphone Mobile Handsfree for Gam...
# 3            3  Super Speed Electric Hand Mixer Egg Beater Cak...
# 4            4                                Electric Hand Mixer
# 5            5  [FLASH SALE] 7 Speed Electric Hand Mixer Egg B...
# 6            6  [FLASH SALE] 7 Speed Electric Hand Mixer Egg B...
# 7            7  Kenwood HM-133 Electric Powered Hand Mixer Whi...
# 8            8  Gionee Wired Earphone Mobile Handsfree for Gam...
# 9            9  7 Speed Hand Mixer Cake Baking Home Handheld S...
# 10          10  Free shipping +Flash Sale】 Microphone Earphone...
# 11          11  [FLASH SALE] 7 Speed Electric Hand Mixer Egg B...
# 12          12  [FLASH SALE] 7 Speed Electric Hand Mixer Egg B...
# ...

# %% [markdown]
# # Question 4

# %% [markdown]
# #### Submit .py file
