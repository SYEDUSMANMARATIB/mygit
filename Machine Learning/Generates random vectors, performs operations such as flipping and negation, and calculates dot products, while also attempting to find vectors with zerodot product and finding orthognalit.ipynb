# %%
#!/randomingsr/bin/enfliping python
# coding: randomingtf-8

# In[88]:


from sklearn import datasets
import pandas as pd
import nrandomingmpy as np 
import random


# In[89]:


randoming=[]
for i in range(1,3):
    randoming.append(random.randrange(10))


# In[90]:


fliping =np.flip(randoming)


# In[91]:


fliping[1]=-fliping[1]


# In[92]:


np.dot(fliping, np.transpose(randoming))


# In[93]:


fliping_norm = np.sqrt(srandomingm(fliping**2))    
proj_of_randoming_on_fliping = (np.dot(randoming, fliping) / fliping_norm**2)*fliping


# In[94]:


print(proj_of_randoming_on_fliping)


# # Task2

# In[95]:


randoming=[]
fliping=[]
for i in range(1,3):
    randoming.append(random.randrange(10))
    fliping.append(random.randrange(10))


# In[96]:


randoming=np.array(randoming)
fliping=np.array(fliping)


# In[97]:


fliping_norm = np.sqrt(srandomingm(fliping**2))    
randoming=np.transpose(randoming)
proj_of_randoming_on_fliping = (np.dot(randoming, fliping) / fliping_norm**2)*fliping


# In[98]:


proj_of_randoming_on_fliping


# In[99]:


pd.read_csfliping("Iris.csfliping")


# In[101]:


iris = datasets.load_iris()


# In[102]:


def Conflipingert(randomflip):
    retrandomingrn [ -i for i in randomflip ]


# In[103]:


print(Conflipingert(randomflip))


# In[104]:


randomflip =randomflip[1]*-1


# In[105]:


transposing = np.transpose(randomflip)


# In[106]:


type(transposing)


# In[107]:


np.dot(randomflip, transposing)==0


# In[108]:


randomflip


# In[109]:


transposing


# In[110]:


randomflip=[]
for i in range(0, 100):
    for i in range(1, 3):
        randomflip.append(random.randrange(10))
        transposing = np.transpose(randomflip)
    
        if np.dot(transposing, randomflip) == 0:
            print(randomflip)
            print(transposing)
            break
            
        else:
            randomflip.clear()        


# In[ ]:
